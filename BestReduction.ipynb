# %%
import bestRowClass as br
import numpy as np
import sympy as sy
import time

# %%
start = time.time()
for i in range(10):
    C = np.random.standard_normal(size=(4,4)) + 1j*np.random.standard_normal(size=(4,4))
    G1 = br.bestReduction(C)
    areas = G1.getAreas()
    print(np.argmin(areas))
finish = time.time()
print(finish - start)
# Out:
# Reduction: 0.015674114227294922
# Regions: 0.7848830223083496
# Reduction: 0.009729623794555664
# Regions: 0.6933178901672363
# Reduction: 0.010653972625732422
# Regions: 0.6069750785827637
# Reduction: 0.009176015853881836
# Regions: 0.6166138648986816
# Calculating the areas: 2.7541699409484863
# 0
# Reduction: 0.009817838668823242
# Regions: 0.6711091995239258
# Reduction: 0.009327173233032227
# Regions: 0.6690430641174316
# Reduction: 0.010220050811767578
# Regions: 0.635087251663208
# Reduction: 0.009156227111816406
# Regions: 0.6501529216766357
# Calculating the areas: 2.670830011367798
# 2
# Reduction: 0.01112985610961914
# Regions: 0.6957540512084961
# Reduction: 0.010282754898071289
# Regions: 0.6986968517303467
# Reduction: 0.009227991104125977
# Regions: 0.6530869007110596
# Reduction: 0.009354829788208008
# Regions: 0.6669938564300537
# Calculating the areas: 2.7612600326538086
# 3
# Reduction: 0.010143041610717773
# Regions: 0.6773519515991211
# ...

# %%
areas
# Out:
# [402, 438, 329, 386]

# %%
s = np.random.uniform(-1,0,1000) + 1j*np.random.uniform(-1,0,1000)
s
# Out:
# array([-0.07789836 -1.84396221e-01j, -0.78357998 -8.92280098e-01j,
#        -0.69756062 -2.28019427e-01j, -0.46531763 -4.19541215e-02j,
#        -0.99432243 -3.45407942e-01j, -0.12938672 -7.07017528e-01j,
#        -0.72763057 -5.01976862e-01j, -0.57405804 -9.91821782e-01j,
#        -0.04810351 -2.85664972e-01j, -0.52086976 -3.36946972e-02j,
#        -0.38963983 -5.92214675e-01j, -0.36549538 -3.52369585e-01j,
#        -0.88115525 -7.39341570e-01j, -0.33995540 -8.23585351e-01j,
#        -0.00671814 -7.12467080e-01j, -0.58257945 -4.42557461e-01j,
#        -0.59414822 -8.43699440e-01j, -0.14072887 -7.68601973e-02j,
#        -0.79450510 -2.89903349e-01j, -0.46032701 -9.40654696e-01j,
#        -0.07999570 -3.58878837e-01j, -0.79506452 -6.59973213e-01j,
#        -0.70011847 -9.28917297e-01j, -0.56499204 -8.26646798e-01j,
#        -0.80791744 -5.05002540e-01j, -0.71112461 -5.07000870e-01j,
#        -0.29768070 -9.27426350e-01j, -0.35918834 -9.56576221e-01j,
# ...
